# %%
import subprocess

# %%
subprocess.run(['ls', './nginx/'])
# Out:
# nginx.conf
# public
# CompletedProcess(args=['ls', './nginx/'], returncode=0)

# %%
subprocess.run(['ab', '-n 1000', '-c 10', 'http://localhost/gunicorn/'])
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1923142 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking localhost (be patient)
# Completed 100 requests
# Completed 200 requests
# Completed 300 requests
# Completed 400 requests
# Completed 500 requests
# Completed 600 requests
# Completed 700 requests
# Completed 800 requests
# Total of 846 requests completed
# apr_pollset_poll: The timeout specified has expired (70007)
# CompletedProcess(args=['ab', '-n 1000', '-c 10', 'http://localhost/gunicorn/'], returncode=119)

# %%
subprocess.run(['ab', '-n 1000', '-c 10', 'http://localhost/public/gabriele-domicolo-rQaV8UUmQdI-unsplash.jpg'])
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1923142 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking localhost (be patient)
# Completed 100 requests
# Completed 200 requests
# Completed 300 requests
# Completed 400 requests
# Completed 500 requests
# Completed 600 requests
# Completed 700 requests
# Completed 800 requests
# Completed 900 requests
# Server Software:        nginx/1.29.8
# Server Hostname:        localhost
# Server Port:            80
#
# Document Path:          /public/gabriele-domicolo-rQaV8UUmQdI-unsplash.jpg
# Document Length:        337899 bytes
#
# Concurrency Level:      10
# Time taken for tests:   6.868 seconds
# Complete requests:      1000
# Failed requests:        0
# Total transferred:      338138000 bytes
# HTML transferred:       337899000 bytes
# Requests per second:    145.61 [#/sec] (mean)
# Time per request:       68.676 [ms] (mean)
# ...

# %% [markdown]
# При RPS `-n 4000 -c 2200` наступает лимит

# %%
subprocess.run(['ab', '-n 4000', '-c 2200', 'http://127.0.0.1:8090/'])
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1923142 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 127.0.0.1 (be patient)
# Completed 400 requests
# Completed 800 requests
# Completed 1200 requests
# Completed 1600 requests
# Completed 2000 requests
# Completed 2400 requests
# Completed 2800 requests
# Completed 3200 requests
# Completed 3600 requests
# Total of 3856 requests completed
# apr_pollset_poll: The timeout specified has expired (70007)
# CompletedProcess(args=['ab', '-n 4000', '-c 2200', 'http://127.0.0.1:8090/'], returncode=119)

# %%
2000*1.10
# Out:
# 2200.0

# %%
subprocess.run(['ab', '-n 4000', '-c 2000', 'http://127.0.0.1:8090/'])
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1923142 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 127.0.0.1 (be patient)
# Completed 400 requests
# Completed 800 requests
# Completed 1200 requests
# Completed 1600 requests
# Completed 2000 requests
# Completed 2400 requests
# Completed 2800 requests
# Completed 3200 requests
# Completed 3600 requests
# Server Software:        gunicorn
# Server Hostname:        127.0.0.1
# Server Port:            8090
#
# Document Path:          /
# Document Length:        30 bytes
#
# Concurrency Level:      2000
# Time taken for tests:   71.339 seconds
# Complete requests:      4000
# Failed requests:        3485
#    (Connect: 0, Receive: 0, Length: 3485, Exceptions: 0)
# Total transferred:      670385 bytes
# HTML transferred:       114385 bytes
# Requests per second:    56.07 [#/sec] (mean)
# ...
